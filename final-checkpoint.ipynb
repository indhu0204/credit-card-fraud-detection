# %%
import pandas as pd

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ### HERE I NOTICE THAT MY TARGET VARIABLE HAS TO CLASS : 1 - WHICH SAYS THE TRANSACTION IS GENUINE & 2 - WHICH SAYS THE TRANSACTION IS FRAUD BY LOOKIING AT IT WE CAN SAY THAT THE DATA IS HIGHLY IMBALANCED

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ### CHECKING FOR NULL VALUES

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df = df.drop(["Time"],axis=1)

# %%
df.head(2)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
#
# [2 rows x 30 columns]

# %% [markdown]
# ### HERE IAM GOING TO STANDARDIZE THE AMOUNT COLUMN IN ORDER TO BRING ALL COLUMNS IN SAME SERIES

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard = StandardScaler()
df["Amount"]=standard.fit_transform(pd.DataFrame(df["Amount"]))

# %%
df.head(2)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  0.244964      0
# 1  0.167170  0.125895 -0.008983  0.014724 -0.342475      0
#
# [2 rows x 30 columns]

# %%
df.shape
# Out:
# (284807, 30)

# %%
df.describe().T
# Out:
#            count          mean       std         min       25%       50%  \
# V1      284807.0  1.168375e-15  1.958696  -56.407510 -0.920373  0.018109
# V2      284807.0  3.416908e-16  1.651309  -72.715728 -0.598550  0.065486
# V3      284807.0 -1.379537e-15  1.516255  -48.325589 -0.890365  0.179846
# V4      284807.0  2.074095e-15  1.415869   -5.683171 -0.848640 -0.019847
# V5      284807.0  9.604066e-16  1.380247 -113.743307 -0.691597 -0.054336
# V6      284807.0  1.487313e-15  1.332271  -26.160506 -0.768296 -0.274187
# V7      284807.0 -5.556467e-16  1.237094  -43.557242 -0.554076  0.040103
# V8      284807.0  1.213481e-16  1.194353  -73.216718 -0.208630  0.022358
# V9      284807.0 -2.406331e-15  1.098632  -13.434066 -0.643098 -0.051429
# V10     284807.0  2.239053e-15  1.088850  -24.588262 -0.535426 -0.092917
# V11     284807.0  1.673327e-15  1.020713   -4.797473 -0.762494 -0.032757
# V12     284807.0 -1.247012e-15  0.999201  -18.683715 -0.405571  0.140033
# ...

# %% [markdown]
# ### CHECKING FOR DUPLICATES

# %%
df.duplicated().any()
### TRUE says that there are duplicates
# Out:
# True

# %%
df.shape
# Out:
# (284807, 30)

# %%
### dropping duplicates
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (275663, 30)

# %%
### checking for duplicares
df.duplicated().any()
# Out:
# False

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the plot
sns.set_style("darkgrid")

# Create a count plot with adjusted scale
ax = sns.countplot(x='Class', data=df)

# Set x-label and y-label
plt.xlabel("Class")
plt.ylabel("Count")

# Add count labels on top of the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

# Show the plot
plt.show()

# %%
### by looking at the graph we can say that the data is highly imbalanced

# %% [markdown]
# ### SO NOW IAM GOING TO SPLIT MY MODEL FOR TRAIN AND TEST SPLIT

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# ### LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_logistic_prediction = log_reg.predict(X_test)

# %%
### checking accuracy score for my model

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_logistic_prediction)
# Out:
# 0.9992563437505668

# %%
### i cant rely only on accuracy score so i am importing few other test aswell

# %%
 from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_logistic_prediction)
# Out:
# 0.890625

# %%
recall_score(y_test,y_logistic_prediction)
# Out:
# 0.6263736263736264

# %%
f1_score(y_test,y_logistic_prediction)
# Out:
# 0.7354838709677419

# %% [markdown]
# ### now when i look into the performance i get to know that there are lot of variance in each perfomance so in order to treat such types we use either over sampling or under sampling to deal with majority and minority of the class and choose whioch model performs better

# %%
### starting with under sampling

# %%
genuine = df[df["Class"]==0]
fraud = df[df["Class"]==1]

# %%
genuine.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
### now when i look the data is imbalanced and in under sampling iam going to balance the data with minority class of the dataset

# %%
genuine_sample = genuine.sample(n=473)

# %%
genuine_sample.shape
# Out:
# (473, 30)

# %%
under_sample_df = pd.concat([genuine_sample,fraud],ignore_index=True)

# %%
under_sample_df["Class"].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
under_sample_df.head(2)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -2.350225  2.461741 -0.327715  2.388222 -0.023057  0.156129 -0.448427
# 1 -0.466544  1.162904 -0.045400  0.487270  0.925027  0.316987  0.574482
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  1.731689 -2.027364 -0.118725  ...  0.291302  0.003028 -0.047649  0.515181
# 1  0.394391 -0.415724 -0.725950  ...  0.225318  0.768357 -0.296050  0.065759
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.037872 -0.220328 -0.815833 -0.146364 -0.353189      0
# 1  0.041552 -0.454367  0.094403  0.119913 -0.315088      0
#
# [2 rows x 30 columns]

# %%
### AND NOW IAM GOING TO SPLIT MODEL AND TRAIN IT WITH LOGISTIC REGRESSION

# %%
X = under_sample_df.drop("Class", axis=1)
y = under_sample_df["Class"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_logistic_prediction = log_reg.predict(X_test)

# %%
accuracy_score(y_test,y_logistic_prediction)
# Out:
# 0.9421052631578948

# %%
precision_score(y_test,y_logistic_prediction)
# Out:
# 0.9789473684210527

# %%
recall_score(y_test,y_logistic_prediction)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_logistic_prediction)
# Out:
# 0.9441624365482234

# %%
#descision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
descison = DecisionTreeClassifier()
descison.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_descision_tree_prediction = descison.predict(X_test)

# %%
accuracy_score(y_test,y_descision_tree_prediction)
# Out:
# 0.8894736842105263

# %%
precision_score(y_test,y_descision_tree_prediction)
# Out:
# 0.900990099009901

# %%
recall_score(,y_dy_testescision_tree_prediction)
# Out:
# 0.8921568627450981

# %%
f1_score(y_test,y_descision_tree_prediction)
# Out:
# 0.896551724137931

# %%
### random forest

# %%
from sklearn.ensemble import RandomForestClassifier
random = RandomForestClassifier()
random.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_random_forest_prediction = random.predict(X_test)

# %%
accuracy_score(y_test,y_random_forest_prediction)
# Out:
# 0.9421052631578948

# %%
precision_score(y_test,y_random_forest_prediction)
# Out:
# 0.989247311827957

# %%
recall_score(y_test,y_random_forest_prediction)
# Out:
# 0.9019607843137255

# %%
f1_score(y_test,y_random_forest_prediction)
# Out:
# 0.9435897435897436

# %%
under_sampling_prediction_accuracy_score = pd.DataFrame({"MODELS" : ["LOGISTIC_REGRESSION","DESCISION_TREE","RANDOM_FOREST"],
              "ACCURACY" : [accuracy_score(y_test,y_logistic_prediction)*100,
                            accuracy_score(y_test,y_descision_tree_prediction)*100,
                            accuracy_score(y_test,y_random_forest_prediction)*100]})

# %%
under_sampling_prediction_precision_score = pd.DataFrame({"MODELS" : ["LOGISTIC_REGRESSION","DESCISION_TREE","RANDOM_FOREST"],
              "precision" : [precision_score(y_test,y_logistic_prediction)*100,
                            precision_score(y_test,y_descision_tree_prediction)*100,
                            precision_score(y_test,y_random_forest_prediction)*100]})

# %%
under_sampling_prediction_accuracy_score
# Out:
#                 MODELS   ACCURACY
# 0  LOGISTIC_REGRESSION  94.210526
# 1       DESCISION_TREE  88.947368
# 2        RANDOM_FOREST  94.210526

# %%
under_sampling_prediction_precision_score
# Out:
#                 MODELS  precision
# 0  LOGISTIC_REGRESSION  97.894737
# 1       DESCISION_TREE  90.099010
# 2        RANDOM_FOREST  98.924731

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")


sns.barplot(x=under_sampling_prediction_accuracy_score["MODELS"], y=under_sampling_prediction_accuracy_score["ACCURACY"])


plt.xticks(rotation=45)

# Set labels and title
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Accuracy of Different Models")


plt.show()

# %%
### let us train with over sampling

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

# %%
X.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
###

# %%
from imblearn.over_sampling import SMOTE

# %%
X_1,y_1 = SMOTE().fit_resample(X,y)

# %%
y_1.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
### as you can the the minority class is now fitted with equal number of class as like the majority class using SMOTE

# %%
 from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_1,y_1,test_size=0.20,random_state=42)

# %%
### LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_LOGISTIC_PREDICTION_2 = log.predict(X_test)

# %%
accuracy_score(y_test,y_LOGISTIC_PREDICTION_2)
# Out:
# 0.943266470438606

# %%
precision_score(y_test,y_LOGISTIC_PREDICTION_2)
# Out:
# 0.9727544213465715

# %%
recall_score(y_test,y_LOGISTIC_PREDICTION_2)
# Out:
# 0.9120047997381961

# %%
f1_score(y_test,y_LOGISTIC_PREDICTION_2)
# Out:
# 0.9414005686349946

# %%
### descision tree

# %%
from sklearn.tree import DecisionTreeClassifier
desc= DecisionTreeClassifier()
desc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_descision_tree_prediction_2 = desc.predict(X_test)

# %%
accuracy_score(y_test,y_descision_tree_prediction_2)
# Out:
# 0.9983375122642538

# %%
precision_score(y_test,y_descision_tree_prediction_2)
# Out:
# 0.9974411092156364

# %%
recall_score(y_test,y_descision_tree_prediction_2)
# Out:
# 0.9992364052869843

# %%
f1_score(y_test,y_descision_tree_prediction_2)
# Out:
# 0.9983379501385041

# %%
### RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
rand = RandomForestClassifier()
rand.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_random_forest_prediction_2 = rand.predict(X_test)

# %%
accuracy_score(y_test,y_random_forest_prediction_2)
# Out:
# 0.999918238308078

# %%
precision_score(y_test,y_random_forest_prediction_2)
# Out:
# 0.9998363993310551

# %%
recall_score(y_test,y_random_forest_prediction_2)
# Out:
# 1.0

# %%
f1_score(y_test,y_random_forest_prediction_2)
# Out:
# 0.9999181929736854

# %%
FINAL = pd.DataFrame({"MODELS" : ["LOGISTIC_REGRESSION","DESCISION_TREE","RANDOM_FOREST"],
              "ACCURACY" : [accuracy_score(y_test,y_LOGISTIC_PREDICTION_2)*100,
                            accuracy_score(y_test,y_descision_tree_prediction_2)*100,
                            accuracy_score(y_test,y_random_forest_prediction_2)*100]})

# %%
FINAL
# Out:
#                 MODELS   ACCURACY
# 0  LOGISTIC_REGRESSION  94.326647
# 1       DESCISION_TREE  99.833751
# 2        RANDOM_FOREST  99.991824

# %%
final_df = RandomForestClassifier()
final_df.fit(X_1,y_1)
# Out:
# RandomForestClassifier()

# %%
# !pip install joblib

# %%
import joblib

# %%
joblib.dump(final_df, "CREDIT_CARD_TRANSACTION_PREDICTION.pkl")
# Out:
# ['CREDIT_CARD_TRANSACTION_PREDICTION.pkl']

# %%
model = joblib.load("CREDIT_CARD_TRANSACTION_PREDICTION.pkl")

# %%
pred = model.predict([[-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62]])
# Out:
# /Users/arav/anaconda3/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
if pred == 0:
    print("normal transaction"):
else:
    print("fraud transaction")
# Out:
#   Cell In[115], line 2
#     print("normal transaction"):
#                                ^
# SyntaxError: invalid syntax
